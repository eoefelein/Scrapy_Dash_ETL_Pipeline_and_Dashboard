# %%
# %reload_ext sql

# %%
from sqlalchemy import create_engine, MetaData, Table
import pymysql

# %%
# connect to DB using sqlalchemy
engine = create_engine("mysql+pymysql://root:UTData20$@localhost:3306/tiny_houses")
conn = engine.connect()
metadata = MetaData(conn)
t = Table("tiny_houses_all", metadata, autoload=True, autoload_with=engine)

# %%
# connect to MySQL DB
# %sql mysql+pymysql://root:UTData20$@localhost:3306/tiny_houses

# %% [markdown]
# ### Initial Exploratory Data Analysis

# %%
# %%sql
# SELECT *
# FROM tiny_house_marketplace
# UNION ALL
# SELECT id, title, property_type, bedrooms, bathrooms, area, city, state, price
# FROM tiny_house_listings
# LIMIT 15
# Out:
#  * mysql+pymysql://root:***@localhost:3306/tiny_houses
# 15 rows affected.
# [(0, '"28\' X 90"" Official Tiny Home Builders Trailer - Discounted Price"', 'Tiny House Trailer', '0', ' 0 ', '224', 'Logan', ' Utah', 6000),
#  (1, "24' TINY HOME READY FOR DELIVERY", 'Tiny House on a Trailer', '2', '1 ', '322', 'rpb', ' Florida', 30000),
#  (2, 'Custom 180 SQ FT Shipping Container Tiny Home', 'Container Home', '0', '1 ', '180', 'Portland', ' OR', 39000),
#  (3, 'Tiny in Greer, SC', 'Tiny House on a Trailer', '1', '1 ', '399', 'Greer', ' SC', 99000),
#  (4, 'Tiny Tudor', 'Tiny House on a Trailer', '1', '1 ', '180', 'Mukwonago', ' WI', 21000),
#  (5, 'Tiny House on Wheels', 'Tiny House on a Trailer', '0', '1 ', '190', 'Colorado Springs', ' Colorado', 37000),
#  (6, 'Tiny House Shell', 'Tiny House Shell on a Trailer', '1', '1 ', '200', 'Noblesville', ' Indiana', 8000),
#  (7, '8x12 Tiny House, Man Cave, Deer Hunting House', 'Container Home', '0', ' 0 ', '100', 'WICHITA', ' Kansas', 9000),
# ...

# %% [markdown]
# ### How many tiny house listings are there per state?

# %%
# %%sql
# SELECT state AS State, count(*) AS Tiny_Home_Count
# FROM tiny_houses_all AS all_house_listings
# GROUP BY state
# Out:
#  * mysql+pymysql://root:***@localhost:3306/tiny_houses
# 52 rows affected.
# [('Alabama', 50),
#  ('Alaska', 6),
#  ('Arizona', 100),
#  ('Arkansas', 32),
#  ('California', 336),
#  ('Colorado', 172),
#  ('Connecticut', 10),
#  ('Delaware', 3),
#  ('District of Columbia', 1),
#  ('Florida', 165),
#  ('Georgia', 88),
#  ('Hawaii', 14),
#  ('Idaho', 50),
#  ('Illinois', 41),
#  ('Indiana', 39),
#  ('Iowa', 20),
#  ('Kansas', 18),
#  ('Kentucky', 37),
#  ('Louisiana', 25),
#  ('Maine', 24),
#  ('Maryland', 15),
#  ('Massachusetts', 28),
#  ('Michigan', 46),
#  ('Minnesota', 26),
#  ('Mississippi', 14),
#  ('Missouri', 47),
#  ('Montana', 34),
#  ('Nebraska', 11),
#  ('Nevada', 22),
#  ('New Hampshire', 23),
#  ('New Jersey', 21),
#  ('New Mexico', 19),
#  ('New York', 61),
#  ('None', 19),
#  ('North Carolina', 93),
#  ('North Dakota', 7),
#  ('Ohio', 56),
#  ('Oklahoma', 48),
#  ('Oregon', 150),
#  ('Pennsylvania', 45),
#  ('Rhode Island', 4),
#  ('South Carolina', 53),
# ...

# %% [markdown]
# ### How many tiny house listings are there?
# Summary statistics provided, excluding outliers

# %%
# %%sql
# SELECT
# count(id) AS tiny_house_total,
# min(price_per_sq_ft) AS min_price,
# FORMAT(avg(price_per_sq_ft),2) AS avg_price,
# max(price_per_sq_ft) AS max_price
# FROM (SELECT * FROM tiny_houses_all WHERE price < 1000000) AS outliers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/tiny_houses
# 1 rows affected.
# [(2745, 0, '192.09', 2500)]
